# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',500)

# %%
BNB_Listings = pd.read_csv("C:\\Users\\A04248\\Desktop\\Boston\\listings.csv")
BNB_Listings.sample(10)
# Out:
#             id                            listing_url       scrape_id  \
# 3261   5590505   https://www.airbnb.com/rooms/5590505  20160906204935
# 1244   9918240   https://www.airbnb.com/rooms/9918240  20160906204935
# 922      27141     https://www.airbnb.com/rooms/27141  20160906204935
# 70     5601743   https://www.airbnb.com/rooms/5601743  20160906204935
# 543   11963384  https://www.airbnb.com/rooms/11963384  20160906204935
# 987    7476340   https://www.airbnb.com/rooms/7476340  20160906204935
# 2073   8814215   https://www.airbnb.com/rooms/8814215  20160906204935
# 542    2706986   https://www.airbnb.com/rooms/2706986  20160906204935
# 1577   9382898   https://www.airbnb.com/rooms/9382898  20160906204935
# 2530   8482847   https://www.airbnb.com/rooms/8482847  20160906204935
#
#      last_scraped                                 name  \
# 3261   2016-09-07      1 bedroom Condo in South Boston
# 1244   2016-09-07                       Elegant Studio
# ...

# %%
BNB_Calender = pd.read_csv("C:\\Users\\A04248\\Desktop\\Boston\\calendar.csv")
BNB_Calender.sample(10)
# Out:
#          listing_id        date available    price
# 1240451    12233830  2017-01-04         t  $194.00
# 706015      6480967  2017-02-02         f      NaN
# 239876     12957423  2017-06-26         t  $186.00
# 927665     12339410  2017-02-08         f      NaN
# 831217      7220216  2017-02-21         f      NaN
# 574888      9531326  2017-08-23         f      NaN
# 1212992     8714682  2017-01-28         f      NaN
# 1241424     6923942  2017-06-15         f      NaN
# 554409      9504177  2016-10-01         f      NaN
# 176162     13000520  2017-01-01         f      NaN

# %%
BNB_Reviews = pd.read_csv("C:\\Users\\A04248\\Desktop\\Boston\\reviews.csv")
BNB_Reviews.sample(10)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 19619     1472481  53177300  2015-11-06     43755656         Khang
# 13434     4924910  29761178  2015-04-12       808018         Munro
# 8086        82637  87699520  2016-07-21     83959996         Ellee
# 47580    11300899  84043994  2016-07-05     34953409          Kate
# 18347       31796  25112588  2015-01-06     24727080         Maxim
# 61626    10231714  58740055  2016-01-04      7958055         Talei
# 51327    11772497  72573765  2016-05-03     25229783       Weishun
# 49637     7724412  43155210  2015-08-17     28932706          Sumi
# 35432     1811776  31524247  2015-05-06     29961249        Angela
# 12716       47521  78953591  2016-06-10     18837845         Timmy
#
#                                                 comments
# 19619  It was great time to stay in CarneyFanily Hous...
# 13434  Anthony is a great host, very welcoming and ac...
# 8086   I so enjoyed staying with Christiane.  Eclecti...
# ...
