# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

pd.set_option('display.max_columns',None)

# %%
## Reading Boston City related data

Boston_Reviews =  pd.read_csv("C:\\Users\\A04248\\Desktop\\Boston\\reviews.csv")

# %%
Boston_Listings.sample(5)
# Out:
#             id                            listing_url       scrape_id  \
# 2111  13836832  https://www.airbnb.com/rooms/13836832  20160906204935
# 3204   2843596   https://www.airbnb.com/rooms/2843596  20160906204935
# 2999   3294775   https://www.airbnb.com/rooms/3294775  20160906204935
# 1482   8737466   https://www.airbnb.com/rooms/8737466  20160906204935
# 638   10106081  https://www.airbnb.com/rooms/10106081  20160906204935
#
#      last_scraped                                 name  \
# 2111   2016-09-07                         New building
# 3204   2016-09-07  Perfect for BCEC!Free bike 3+ night
# 2999   2016-09-07   Sea view near metro & city center!
# 1482   2016-09-07      Elegant studio, heart of Boston
# 638    2016-09-07   In the heart of North End, Boston.
#
#                                                 summary  \
# 2111  My place is close to W hotel, Boston Commons p...
# 3204  Perfectly charming, quaint room in our South B...
# 2999  Charming Victorian hill-top house, pleasant re...
# 1482  Fantastic location! Across the street from Bos...
# 638   Newly renovated one bedroom apartment. It is l...
#
#                                                   space  \
# 2111                                                NaN
# 3204  This room is about 8x9ft, so quaint and has a ...
# 2999  Ocean views from most windows, ocean breezes, ...
# 1482  Heigh ceilings, historic building in a modern ...
# 638                                                 NaN
#
#                                             description experiences_offered  \
# 2111  My place is close to W hotel, Boston Commons p...                none
# 3204  Perfectly charming, quaint room in our South B...                none
# 2999  Charming Victorian hill-top house, pleasant re...                none
# 1482  Fantastic location! Across the street from Bos...                none
# 638   Newly renovated one bedroom apartment. It is l...                none
#
#                                   neighborhood_overview  \
# 2111                                                NaN
# 3204  I love that our neighborhood is in the city, y...
# 2999  Jones Hill is a quiet, safe residential neighb...
# 1482  Across the park, two minutes walk to downton B...
# 638                                                 NaN
#
#                                                   notes  \
# 2111                                                NaN
# 3204  As noted, I have a 2.5-year-old and an 8 month...
# 2999  We have extra guitars and other acoustic instr...
# 1482         Pet friendly, the neighberhood is the best
# 638                                                 NaN
#
#                                                 transit  \
# 2111                                                NaN
# 3204  ***Please inquire with me if you are intereste...
# 2999  Close to shops and good restaurants, only eigh...
# 1482  Green line Arlington station, walking distance...
# 638   3-5 min walk from the subway station (orange a...
#
#                                                  access  \
# 2111                                                NaN
# 3204  We often have fruit, cookies, granola bars, co...
# 2999  Rooms are fully furnished; shared kitchen full...
# 1482  Laundry in the basement, full time access to r...
# 638                                                 NaN
#
#                                             interaction  \
# 2111                                                NaN
# 3204  Someone is usually always present, but we get ...
# 2999  I live in the house; if I am not travelling, I...
# 1482                                                NaN
# 638                                                 NaN
#
#                                             house_rules  \
# 2111                                                NaN
# 3204  No smoking inside. Please go in our backyard i...
# 2999  Guests who use kitchen must wash their dishes ...
# 1482  Treat everything as if it was yours! Enjoy you...
# 638            Please no dirty dishes behind. Thank you
#
#                                           thumbnail_url  \
# 2111  https://a2.muscache.com/im/pictures/2096e254-8...
# 3204  https://a2.muscache.com/im/pictures/c77ffa32-1...
# 2999  https://a0.muscache.com/im/pictures/41816373/d...
# 1482  https://a2.muscache.com/im/pictures/111143285/...
# 638                                                 NaN
#
#                                              medium_url  \
# 2111  https://a2.muscache.com/im/pictures/2096e254-8...
# 3204  https://a2.muscache.com/im/pictures/c77ffa32-1...
# 2999  https://a0.muscache.com/im/pictures/41816373/d...
# 1482  https://a2.muscache.com/im/pictures/111143285/...
# 638                                                 NaN
#
#                                             picture_url  \
# 2111  https://a2.muscache.com/im/pictures/2096e254-8...
# 3204  https://a2.muscache.com/im/pictures/c77ffa32-1...
# 2999  https://a0.muscache.com/im/pictures/41816373/d...
# 1482  https://a2.muscache.com/im/pictures/111143285/...
# 638   https://a2.muscache.com/im/pictures/6fa8d388-2...
#
#                                          xl_picture_url   host_id  \
# 2111  https://a2.muscache.com/im/pictures/2096e254-8...  81626490
# 3204  https://a2.muscache.com/im/pictures/c77ffa32-1...   3351569
# 2999  https://a0.muscache.com/im/pictures/41816373/d...   9898255
# 1482  https://a2.muscache.com/im/pictures/111143285/...  45840601
# 638                                                 NaN  40885583
#
#                                         host_url     host_name  host_since  \
# 2111  https://www.airbnb.com/users/show/81626490          Mike  2016-07-04
# 3204   https://www.airbnb.com/users/show/3351569       Monique  2012-08-23
# 2999   https://www.airbnb.com/users/show/9898255       Jessica  2013-11-09
# 1482  https://www.airbnb.com/users/show/45840601          Raul  2015-10-05
# 638   https://www.airbnb.com/users/show/40885583  Konstantinos  2015-08-08
#
#                               host_location  \
# 2111   Boston, Massachusetts, United States
# 3204   Boston, Massachusetts, United States
# 2999   Boston, Massachusetts, United States
# 1482                                     US
# 638   Hanover, New Hampshire, United States
#
#                                              host_about  host_response_time  \
# 2111                                                NaN        within a day
# 3204  Hi all,\r\nMy name is Monique and I love livin...      within an hour
# 2999  I am a health psychologist and music therapist...      within an hour
# 1482                                                NaN  within a few hours
# 638                                                 NaN  within a few hours
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 2111                63%                 100%                 f
# 3204               100%                 100%                 f
# 2999               100%                  96%                 f
# 1482               100%                  64%                 f
# 638                100%                  61%                 t
#
#                                      host_thumbnail_url  \
# 2111  https://a2.muscache.com/im/pictures/478e61a9-8...
# 3204  https://a1.muscache.com/im/users/3351569/profi...
# 2999  https://a2.muscache.com/im/users/9898255/profi...
# 1482  https://a2.muscache.com/im/users/45840601/prof...
# 638   https://a2.muscache.com/im/pictures/4745e3a3-f...
#
#                                        host_picture_url host_neighbourhood  \
# 2111  https://a2.muscache.com/im/pictures/478e61a9-8...                NaN
# 3204  https://a1.muscache.com/im/users/3351569/profi...       South Boston
# 2999  https://a2.muscache.com/im/users/9898255/profi...         Dorchester
# 1482  https://a2.muscache.com/im/users/45840601/prof...           Back Bay
# 638   https://a2.muscache.com/im/pictures/4745e3a3-f...          North End
#
#       host_listings_count  host_total_listings_count  \
# 2111                    1                          1
# 3204                    1                          1
# 2999                    4                          4
# 1482                    1                          1
# 638                     1                          1
#
#                                      host_verifications host_has_profile_pic  \
# 2111                                 ['email', 'phone']                    t
# 3204               ['email', 'phone', 'reviews', 'kba']                    t
# 2999               ['email', 'phone', 'reviews', 'kba']                    t
# 1482  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 638   ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#      host_identity_verified  \
# 2111                      f
# 3204                      t
# 2999                      t
# 1482                      t
# 638                       t
#
#                                                  street neighbourhood  \
# 2111     Stuart Street, Boston, MA 02116, United States           NaN
# 3204   East 4th Street, Boston, MA 02127, United States  South Boston
# 2999   Peverell Street, Boston, MA 02125, United States    Dorchester
# 1482  Marlborough Street, Boston, MA 02116, United S...      Back Bay
# 638       Salem Street, Boston, MA 02113, United States     North End
#
#      neighbourhood_cleansed  neighbourhood_group_cleansed    city state  \
# 2111               Downtown                           NaN  Boston    MA
# 3204           South Boston                           NaN  Boston    MA
# 2999             Dorchester                           NaN  Boston    MA
# 1482               Back Bay                           NaN  Boston    MA
# 638               North End                           NaN  Boston    MA
#
#      zipcode  market smart_location country_code        country   latitude  \
# 2111   02116  Boston     Boston, MA           US  United States  42.350716
# 3204   02127  Boston     Boston, MA           US  United States  42.334096
# 2999   02125  Boston     Boston, MA           US  United States  42.314178
# 1482   02116  Boston     Boston, MA           US  United States  42.353280
# 638    02113  Boston     Boston, MA           US  United States  42.366465
#
#       longitude is_location_exact property_type        room_type  \
# 2111 -71.064290                 f     Apartment  Entire home/apt
# 3204 -71.028288                 t     Apartment     Private room
# 2999 -71.060367                 t         House     Private room
# 1482 -71.071689                 t     Apartment  Entire home/apt
# 638  -71.053757                 t     Apartment  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 2111             4        1.0       2.0   2.0  Real Bed
# 3204             1        1.5       1.0   1.0  Real Bed
# 2999             2        2.5       1.0   1.0  Real Bed
# 1482             2        1.0       0.0   1.0  Real Bed
# 638              2        1.0       1.0   2.0  Real Bed
#
#                                               amenities  square_feet    price  \
# 2111  {TV,"Air Conditioning",Kitchen,Gym,"Elevator i...          NaN  $199.00
# 3204  {Internet,"Wireless Internet","Air Conditionin...          NaN  $103.00
# 2999  {"Cable TV",Internet,"Wireless Internet",Kitch...          NaN   $65.00
# 1482  {TV,Internet,"Wireless Internet","Air Conditio...          NaN  $169.00
# 638   {Internet,"Wireless Internet","Air Conditionin...          NaN  $180.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 2111          NaN           NaN          $300.00          NaN
# 3204          NaN           NaN              NaN        $5.00
# 2999      $450.00     $1,800.00              NaN       $10.00
# 1482          NaN           NaN              NaN       $45.00
# 638           NaN           NaN              NaN       $80.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 2111                1        $0.00              10              30
# 3204                0        $0.00               1            1125
# 2999                1       $20.00               2            1125
# 1482                1       $50.00               5            1125
# 638                 2        $0.00               2            1125
#
#      calendar_updated  has_availability  availability_30  availability_60  \
# 2111      4 weeks ago               NaN                0                0
# 3204       a week ago               NaN               19               40
# 2999            today               NaN               11               26
# 1482      3 weeks ago               NaN               18               43
# 638        2 days ago               NaN                3               24
#
#       availability_90  availability_365 calendar_last_scraped  \
# 2111                0                 0            2016-09-06
# 3204               70               345            2016-09-06
# 2999               48               275            2016-09-06
# 1482               73               348            2016-09-06
# 638                54               144            2016-09-06
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 2111                  0          NaN         NaN                   NaN
# 3204                 79   2014-05-17  2016-08-29                  95.0
# 2999                 62   2014-07-01  2016-08-21                  91.0
# 1482                 10   2015-10-09  2016-09-02                  97.0
# 638                  25   2016-01-15  2016-09-05                  97.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2111                     NaN                        NaN
# 3204                    10.0                       10.0
# 2999                     9.0                        9.0
# 1482                    10.0                        9.0
# 638                     10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 2111                    NaN                          NaN
# 3204                   10.0                         10.0
# 2999                   10.0                         10.0
# 1482                   10.0                         10.0
# 638                    10.0                         10.0
#
#       review_scores_location  review_scores_value requires_license  license  \
# 2111                     NaN                  NaN                f      NaN
# 3204                     9.0                  9.0                f      NaN
# 2999                     9.0                  9.0                f      NaN
# 1482                    10.0                 10.0                f      NaN
# 638                     10.0                 10.0                f      NaN
#
#       jurisdiction_names instant_bookable cancellation_policy  \
# 2111                 NaN                t            flexible
# 3204                 NaN                t            moderate
# 2999                 NaN                f            flexible
# 1482                 NaN                f              strict
# 638                  NaN                f              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 2111                             f                                f
# 3204                             f                                t
# 2999                             f                                f
# 1482                             f                                f
# 638                              f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 2111                               1                NaN
# 3204                               1               2.80
# 2999                               4               2.33
# 1482                               1               0.90
# 638                                1               3.16

# %%
Boston_Reviews.sample(5)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 62673     2174711  18445982  2014-08-26     18164831         Evans
# 36199     1695275  10833099  2014-03-10      3222633        Andrea
# 23410    13674701  97456175  2016-08-27     82866223      Angelica
# 22758      257588  73100656  2016-05-06     46966823        Tamsen
# 30375     1203014  90191922  2016-07-31     39395560         Laura
#
#                                                 comments
# 62673  Our experience could not have been better. Wha...
# 36199  Excellent apartment and just what I needed for...
# 23410  The listing description was very accurate and ...
# 22758  Meri's apartment in South Boston was an excell...
# 30375  great convo with the host; easy access to oran...

# %%
print('Boston_Reviews Shape',  Boston_Reviews.shape,'\n')

#print(Boston_Listings.columns)
# Out:
# Boston_Listings Shape (3585, 95)
#
# Boston_Reviews Shape (68275, 6)

# %%
## Reading Seattle City related data

Seattle_Reviews = pd.read_csv("C:\\Users\\A04248\\Desktop\\Seattle\\reviews.csv")

# %%
Seattle_Reviews.sample(5)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 73287     1856970  25917446  2015-01-29      4654793         Kevin
# 47761     3992155  51115356  2015-10-18     36080230         Marie
# 35451     3615614  21100671  2014-10-11     21927816         Marie
# 82674     3552523  29396221  2015-04-07     20335593          Eric
# 16997     1601714  15745220  2014-07-15      1420924         Danny
#
#                                                 comments
# 73287  Carol was a fantastic and friendly host. I fou...
# 47761  Even though we didn't meet Kevin in person, hi...
# 35451  TJ is a wonderfull host! Her place is very coz...
# 82674  Great location, very walkable area. Nice room ...
# 16997  The place was great, lots of space and a wonde...

# %%
print('Seattle_Reviews Shape',  Seattle_Reviews.shape)

#print(Seattle_Listings.columns)
# Out:
# Seattle_Listings Shape (3818, 92)
# Seattle_Reviews Shape (84849, 6)

# %%
#Travellers Graph

Boston_Reviews['date'] = pd.to_datetime(Boston_Reviews['date'])
print(Boston_Reviews['date'].info())
print('Min Review Date',Boston_Reviews['date'].min())
print('Max Review Date',Boston_Reviews['date'].max())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 68275 entries, 0 to 68274
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 68275 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 533.5 KB
# None
# Min Review Date 2009-03-21 00:00:00
# Max Review Date 2016-09-06 00:00:00

# %%
Boston_Reviews['Year'] = Boston_Reviews['date'].dt.year
Boston_Reviews
# Out:
#        listing_id        id       date  reviewer_id reviewer_name  \
# 0         1178162   4724140 2013-05-21      4298113       Olivier
# 1         1178162   4869189 2013-05-29      6452964     Charlotte
# 2         1178162   5003196 2013-06-06      6449554     Sebastian
# 3         1178162   5150351 2013-06-15      2215611        Marine
# 4         1178162   5171140 2013-06-16      6848427        Andrew
# ...           ...       ...        ...          ...           ...
# 68270     7462268  80537457 2016-06-18     22034145       Antonio
# 68271     7462268  83640094 2016-07-03     40052513         Steve
# 68272     7462268  85797088 2016-07-13     77129134          Nick
# 68273     7462268  97264637 2016-08-26     15799803           Vid
# 68274     7462268  98550693 2016-08-31     90128094       Arianna
#
#                                                 comments  Year
# 0      My stay at islam's place was really cool! Good...  2013
# 1      Great location for both airport and city - gre...  2013
# 2      We really enjoyed our stay at Islams house. Fr...  2013
# 3      The room was nice and clean and so were the co...  2013
# 4      Great location. Just 5 mins walk from the Airp...  2013
# ...                                                  ...   ...
# 68270  Joe y su mujer son encantadores. La habitación...  2016
# 68271  Joe was on his way to Jamaica to be married! o...  2016
# 68272  The room was very clean as were the bathrooms ...  2016
# 68273  Staying in Lower Allston at Joe and Nancy's pl...  2016
# 68274  The room itself and the aprtment were very cle...  2016
#
# [68275 rows x 7 columns]

# %%
Boston_Reviews.groupby(['Year'])['reviewer_id'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Boston_Reviews.groupby(['Year'])['reviewer_id'].count().plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Seattle_Reviews['date'] = pd.to_datetime(Seattle_Reviews['date'])
print(Seattle_Reviews['date'].info())
print('Min Review Date',Seattle_Reviews['date'].min())
print('Max Review Date',Seattle_Reviews['date'].max())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 84849 entries, 0 to 84848
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 84849 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 663.0 KB
# None
# Min Review Date 2009-06-07 00:00:00
# Max Review Date 2016-01-03 00:00:00

# %%
Seattle_Reviews['Year'] = Seattle_Reviews['date'].dt.year
Seattle_Reviews
# Out:
#        listing_id        id       date  reviewer_id reviewer_name  \
# 0         7202016  38917982 2015-07-19     28943674        Bianca
# 1         7202016  39087409 2015-07-20     32440555         Frank
# 2         7202016  39820030 2015-07-26     37722850           Ian
# 3         7202016  40813543 2015-08-02     33671805        George
# 4         7202016  41986501 2015-08-10     34959538          Ming
# ...           ...       ...        ...          ...           ...
# 84844     3624990  50436321 2015-10-12     37419458          Ryan
# 84845     3624990  51024875 2015-10-17      6933252         Linda
# 84846     3624990  51511988 2015-10-20     19543701         Jaime
# 84847     3624990  52814482 2015-11-02     24445024        Jørgen
# 84848     9727246  56429621 2015-12-13     30860360     Stephanie
#
#                                                 comments  Year
# 0      Cute and cozy place. Perfect location to every...  2015
# 1      Kelly has a great room in a very central locat...  2015
# 2      Very spacious apartment, and in a great neighb...  2015
# 3      Close to Seattle Center and all it has to offe...  2015
# 4      Kelly was a great host and very accommodating ...  2015
# ...                                                  ...   ...
# 84844  The description and pictures of the apartment ...  2015
# 84845  We had an excellent stay. It was clean and com...  2015
# 84846  Gran ubicación, cerca de todo lo atractivo del...  2015
# 84847  Very good apartement, clean and well sized. Si...  2015
# 84848  Breanne was a great host. Check in was easy, s...  2015
#
# [84849 rows x 7 columns]

# %%
Seattle_Reviews.groupby(['Year'])['reviewer_id'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Seattle_Reviews.groupby(['Year'])['reviewer_id'].count().plot()
# Out:
# <AxesSubplot:xlabel='Year'>
