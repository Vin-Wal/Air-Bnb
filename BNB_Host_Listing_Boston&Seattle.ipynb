# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

pd.set_option('display.max_columns',None)

# %%
## Reading Boston City related data

Boston_Listings = pd.read_csv("C:\\Users\\A04248\\Desktop\\Boston\\listings.csv")

# %%
Boston_Listings.sample(5)
# Out:
#             id                            listing_url       scrape_id  \
# 650   14104621  https://www.airbnb.com/rooms/14104621  20160906204935
# 2726   8645254   https://www.airbnb.com/rooms/8645254  20160906204935
# 1573   8859689   https://www.airbnb.com/rooms/8859689  20160906204935
# 2861   7842550   https://www.airbnb.com/rooms/7842550  20160906204935
# 1523  12998272  https://www.airbnb.com/rooms/12998272  20160906204935
#
#      last_scraped                                name  \
# 650    2016-09-07  Simple, comfortable and convenient
# 2726   2016-09-07                  Lovely, Quiet Room
# 1573   2016-09-07      Lux Boston 2 BR Apt near train
# 2861   2016-09-07                       lovely family
# 1523   2016-09-07  2 bedroom in the heart of Back Bay
#
#                                                 summary  \
# 650   My place is in the North End and close to TD G...
# 2726  My 11-year-old daughter and I love hosting fem...
# 1573  Private apartment with access to FREE airport ...
# 2861  i live in my 2 bedrooms apartment in a 3 famil...
# 1523  My place is a short walk to Fenway Park, The S...
#
#                                                   space  \
# 650                                                 NaN
# 2726                                                NaN
# 1573  Our condo is a penthouse condo/apartment with ...
# 2861                                                NaN
# 1523                                                NaN
#
#                                             description experiences_offered  \
# 650   My place is in the North End and close to TD G...                none
# 2726  My 11-year-old daughter and I love hosting fem...                none
# 1573  Private apartment with access to FREE airport ...                none
# 2861  i live in my 2 bedrooms apartment in a 3 famil...                none
# 1523  My place is a short walk to Fenway Park, The S...                none
#
#                                   neighborhood_overview  \
# 650                                                 NaN
# 2726  Hyde Park is a quiet residential neighborhood ...
# 1573  The location of our apartment makes it feasibl...
# 2861                                                NaN
# 1523                                                NaN
#
#                                                   notes  \
# 650                                                 NaN
# 2726                                                NaN
# 1573  We expect that you treat our home as you would...
# 2861                                                NaN
# 1523                                                NaN
#
#                                                 transit  \
# 650                                                 NaN
# 2726  Easy walk to commuter rail or bus/subway to do...
# 1573  The easiest way to get around is by using the ...
# 2861                                                NaN
# 1523                                                NaN
#
#                                                  access  \
# 650                                                 NaN
# 2726  Access to kitchen, half bath next to room, and...
# 1573  Entire top floor apartment and exclusive back ...
# 2861                                                NaN
# 1523                                                NaN
#
#                                             interaction  \
# 650                                                 NaN
# 2726  Warm, welcoming family: mom and wonderful 11-y...
# 1573  We will be available for any of your needs, we...
# 2861                                                NaN
# 1523                                                NaN
#
#                                             house_rules  \
# 650                                                 NaN
# 2726  No smoking.  No guests without previous discus...
# 1573  We expect that you treat our home as you would...
# 2861                                 No pets No alcohol
# 1523                                                NaN
#
#                                           thumbnail_url  \
# 650   https://a2.muscache.com/im/pictures/162d8e89-b...
# 2726  https://a0.muscache.com/im/pictures/109842499/...
# 1573  https://a2.muscache.com/im/pictures/669a3086-2...
# 2861  https://a1.muscache.com/im/pictures/99861430/9...
# 1523  https://a2.muscache.com/im/pictures/10771fbc-5...
#
#                                              medium_url  \
# 650   https://a2.muscache.com/im/pictures/162d8e89-b...
# 2726  https://a0.muscache.com/im/pictures/109842499/...
# 1573  https://a2.muscache.com/im/pictures/669a3086-2...
# 2861  https://a1.muscache.com/im/pictures/99861430/9...
# 1523  https://a2.muscache.com/im/pictures/10771fbc-5...
#
#                                             picture_url  \
# 650   https://a2.muscache.com/im/pictures/162d8e89-b...
# 2726  https://a0.muscache.com/im/pictures/109842499/...
# 1573  https://a2.muscache.com/im/pictures/669a3086-2...
# 2861  https://a1.muscache.com/im/pictures/99861430/9...
# 1523  https://a2.muscache.com/im/pictures/10771fbc-5...
#
#                                          xl_picture_url   host_id  \
# 650   https://a2.muscache.com/im/pictures/162d8e89-b...  84922021
# 2726  https://a0.muscache.com/im/pictures/109842499/...  41306542
# 1573  https://a2.muscache.com/im/pictures/669a3086-2...  44617326
# 2861  https://a1.muscache.com/im/pictures/99861430/9...  11341278
# 1523  https://a2.muscache.com/im/pictures/10771fbc-5...  71647340
#
#                                         host_url host_name  host_since  \
# 650   https://www.airbnb.com/users/show/84922021   Lindsay  2016-07-20
# 2726  https://www.airbnb.com/users/show/41306542     Becky  2015-08-12
# 1573  https://www.airbnb.com/users/show/44617326  Caroline  2015-09-19
# 2861  https://www.airbnb.com/users/show/11341278     Sarah  2014-01-15
# 1523  https://www.airbnb.com/users/show/71647340     Chris  2016-05-12
#
#                              host_location  \
# 650   Boston, Massachusetts, United States
# 2726  Boston, Massachusetts, United States
# 1573  Boston, Massachusetts, United States
# 2861  Boston, Massachusetts, United States
# 1523  Boston, Massachusetts, United States
#
#                                              host_about  host_response_time  \
# 650                                                 NaN      within an hour
# 2726  I'm a long-time Boston resident with lots of t...  within a few hours
# 1573  My broad background and entrepreneurial mindse...      within an hour
# 2861  i live with my 3 years daughter \r\ni would lo...      within an hour
# 1523                                                NaN        within a day
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 650                100%                 100%                 f
# 2726               100%                  33%                 f
# 1573               100%                 100%                 f
# 2861               100%                 100%                 f
# 1523                78%                  67%                 f
#
#                                      host_thumbnail_url  \
# 650   https://a2.muscache.com/im/pictures/5bdcdd1c-c...
# 2726  https://a1.muscache.com/im/users/41306542/prof...
# 1573  https://a2.muscache.com/im/pictures/ffa7cebb-7...
# 2861  https://a0.muscache.com/im/users/11341278/prof...
# 1523  https://a2.muscache.com/im/pictures/a95124ec-1...
#
#                                        host_picture_url host_neighbourhood  \
# 650   https://a2.muscache.com/im/pictures/5bdcdd1c-c...          North End
# 2726  https://a1.muscache.com/im/users/41306542/prof...          Hyde Park
# 1573  https://a2.muscache.com/im/pictures/ffa7cebb-7...        East Boston
# 2861  https://a0.muscache.com/im/users/11341278/prof...            Roxbury
# 1523  https://a2.muscache.com/im/pictures/a95124ec-1...           Back Bay
#
#       host_listings_count  host_total_listings_count  \
# 650                     1                          1
# 2726                    2                          2
# 1573                    3                          3
# 2861                    1                          1
# 1523                    1                          1
#
#                                      host_verifications host_has_profile_pic  \
# 650   ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 2726   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1573             ['email', 'phone', 'reviews', 'jumio']                    t
# 2861               ['email', 'phone', 'reviews', 'kba']                    t
# 1523          ['email', 'phone', 'facebook', 'reviews']                    t
#
#      host_identity_verified  \
# 650                       t
# 2726                      t
# 1573                      t
# 2861                      t
# 1523                      f
#
#                                                  street neighbourhood  \
# 650    Tileston Street, Boston, MA 02113, United States     North End
# 2726        Elm Street, Boston, MA 02136, United States     Hyde Park
# 1573    Chelsea Street, Boston, MA 02128, United States           NaN
# 2861   Stanwood Street, Boston, MA 02121, United States       Roxbury
# 1523  Commonwealth Avenue, Boston, MA 02115, United ...      Back Bay
#
#      neighbourhood_cleansed  neighbourhood_group_cleansed    city state  \
# 650               North End                           NaN  Boston    MA
# 2726              Hyde Park                           NaN  Boston    MA
# 1573            East Boston                           NaN  Boston    MA
# 2861             Dorchester                           NaN  Boston    MA
# 1523               Back Bay                           NaN  Boston    MA
#
#      zipcode  market smart_location country_code        country   latitude  \
# 650    02113  Boston     Boston, MA           US  United States  42.365919
# 2726   02136  Boston     Boston, MA           US  United States  42.259704
# 1573   02128  Boston     Boston, MA           US  United States  42.375747
# 2861   02121  Boston     Boston, MA           US  United States  42.307605
# 1523   02115     NaN     Boston, MA           US  United States  42.348922
#
#       longitude is_location_exact property_type        room_type  \
# 650  -71.053142                 t     Apartment  Entire home/apt
# 2726 -71.119365                 t         House     Private room
# 1573 -71.029894                 f     Apartment  Entire home/apt
# 2861 -71.079769                 t         House     Private room
# 1523 -71.090355                 t     Apartment  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 650              2        1.0       1.0   1.0  Real Bed
# 2726             1        0.5       1.0   1.0  Real Bed
# 1573             5        1.0       2.0   2.0  Real Bed
# 2861             2        1.0       1.0   2.0  Real Bed
# 1523             5        1.0       2.0   3.0  Real Bed
#
#                                               amenities  square_feet    price  \
# 650   {TV,"Wireless Internet","Air Conditioning",Kit...          NaN  $200.00
# 2726  {TV,"Wireless Internet","Air Conditioning",Kit...          NaN   $45.00
# 1573  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  $250.00
# 2861  {"Wireless Internet",Kitchen,"Family/Kid Frien...          NaN   $45.00
# 1523  {TV,"Wireless Internet","Air Conditioning",Kit...          NaN  $286.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 650           NaN           NaN              NaN          NaN
# 2726      $300.00       $850.00              NaN          NaN
# 1573    $1,100.00     $3,500.00          $250.00       $95.00
# 2861          NaN           NaN              NaN          NaN
# 1523          NaN           NaN              NaN      $100.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 650                 1        $0.00               1            1125
# 2726                1        $0.00               1            1125
# 1573                4       $35.00               1            1125
# 2861                1       $20.00               1            1125
# 1523                4       $50.00               1            1125
#
#      calendar_updated  has_availability  availability_30  availability_60  \
# 650        4 days ago               NaN                0                0
# 2726      2 weeks ago               NaN                0                6
# 1573            today               NaN                6               18
# 2861       a week ago               NaN               20               49
# 1523       3 days ago               NaN                9               25
#
#       availability_90  availability_365 calendar_last_scraped  \
# 650                 3                 3            2016-09-06
# 2726               36               311            2016-09-06
# 1573               47               322            2016-09-06
# 2861               79               106            2016-09-06
# 1523               55               330            2016-09-06
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 650                   1   2016-08-14  2016-08-14                 100.0
# 2726                  1   2016-04-24  2016-04-24                   NaN
# 1573                 15   2015-11-28  2016-08-19                  94.0
# 2861                 47   2015-08-24  2016-09-04                  83.0
# 1523                  1   2016-09-05  2016-09-05                 100.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 650                     10.0                       10.0
# 2726                     NaN                        NaN
# 1573                    10.0                       10.0
# 2861                     9.0                        9.0
# 1523                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 650                    10.0                         10.0
# 2726                    NaN                          NaN
# 1573                   10.0                         10.0
# 2861                    9.0                          9.0
# 1523                   10.0                         10.0
#
#       review_scores_location  review_scores_value requires_license  license  \
# 650                     10.0                 10.0                f      NaN
# 2726                     NaN                  NaN                f      NaN
# 1573                     9.0                 10.0                f      NaN
# 2861                     7.0                  9.0                f      NaN
# 1523                    10.0                 10.0                f      NaN
#
#       jurisdiction_names instant_bookable cancellation_policy  \
# 650                  NaN                t            flexible
# 2726                 NaN                f            flexible
# 1573                 NaN                t            moderate
# 2861                 NaN                t            moderate
# 1523                 NaN                f            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 650                              f                                f
# 2726                             f                                f
# 1573                             f                                f
# 2861                             f                                f
# 1523                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 650                                1               1.00
# 2726                               2               0.22
# 1573                               3               1.58
# 2861                               1               3.70
# 1523                               1               1.00

# %%
print('Boston_Listings Shape', Boston_Listings.shape,'\n')

#print(Boston_Listings.columns)
# Out:
# Boston_Listings Shape (3585, 95)

# %%
## Reading Seattle City related data

Seattle_Listings = pd.read_csv("C:\\Users\\A04248\\Desktop\\Seattle\\listings.csv")

# %%
Seattle_Listings.sample(5)
# Out:
#            id                           listing_url       scrape_id  \
# 3809  6120046  https://www.airbnb.com/rooms/6120046  20160104002432
# 2656  9137075  https://www.airbnb.com/rooms/9137075  20160104002432
# 3265  2303981  https://www.airbnb.com/rooms/2303981  20160104002432
# 1359  5784320  https://www.airbnb.com/rooms/5784320  20160104002432
# 3554  6592178  https://www.airbnb.com/rooms/6592178  20160104002432
#
#      last_scraped                                 name  \
# 3809   2016-01-04        Lake Veiw Cottage  in Fremont
# 2656   2016-01-04   Capitol Hill Craftsman Corner View
# 3265   2016-01-04  A Quintessential Seattle-area Home
# 1359   2016-01-04   Seattle's Best Downtown Condo! MT2
# 3554   2016-01-04  Lofted urban retreat with roof deck
#
#                                                 summary  \
# 3809  From the deck of this quaint little apartment ...
# 2656  Beautiful spacious room in an old Craftsman pr...
# 3265  Our spacious 3 bedroom apartment is the first ...
# 1359  The Metropolitan Tower property is centrally l...
# 3554  Bright and airy, three-story open loft in Capi...
#
#                                                   space  \
# 3809  This one bedroom apartment (Hippy Shack) is de...
# 2656  Corner View has a spacious and relaxing vibe w...
# 3265  This is a very large, extremely comfortable ho...
# 1359  AMAZING BUILDING, AMENITIES, AND LOCATION WITH...
# 3554  Spacious, architect-designed three-story loft ...
#
#                                             description experiences_offered  \
# 3809  From the deck of this quaint little apartment ...                none
# 2656  Beautiful spacious room in an old Craftsman pr...                none
# 3265  Our spacious 3 bedroom apartment is the first ...                none
# 1359  The Metropolitan Tower property is centrally l...                none
# 3554  Bright and airy, three-story open loft in Capi...                none
#
#                                   neighborhood_overview  \
# 3809  This cottage apartment is located just a few b...
# 2656  The location is truly central to the unique an...
# 3265  This is the extreme western side of Crown Hill...
# 1359  In the heart of Downtown Seattle! Nearby Attra...
# 3554  The place is ideally located in the Capitol Hi...
#
#                                                   notes  \
# 3809  1. Is the property quite private? ie. can we s...
# 2656  Parking! Parking is not ideal in our dense & c...
# 3265  Although we describe this as an apartment, thi...
# 1359  All of our rentals are fully licensed and regu...
# 3554  Being a loft space, the floors are open to one...
#
#                                                 transit  \
# 3809  This cottage apartment is located just a few b...
# 2656  We are a fifteen minute walk from Convention c...
# 3265  The Seattle Metro bus line runs close by, on 1...
# 1359  Convenient public transportation. The location...
# 3554  Direct bus lines to downtown, University of Wa...
#
#                                           thumbnail_url  \
# 3809  https://a2.muscache.com/ac/pictures/76273783/b...
# 2656  https://a2.muscache.com/ac/pictures/8e4c1481-4...
# 3265  https://a2.muscache.com/ac/pictures/30857708/1...
# 1359  https://a2.muscache.com/ac/pictures/77774969/7...
# 3554  https://a0.muscache.com/ac/pictures/83335935/9...
#
#                                              medium_url  \
# 3809  https://a2.muscache.com/im/pictures/76273783/b...
# 2656  https://a2.muscache.com/im/pictures/8e4c1481-4...
# 3265  https://a2.muscache.com/im/pictures/30857708/1...
# 1359  https://a2.muscache.com/im/pictures/77774969/7...
# 3554  https://a0.muscache.com/im/pictures/83335935/9...
#
#                                             picture_url  \
# 3809  https://a2.muscache.com/ac/pictures/76273783/b...
# 2656  https://a2.muscache.com/ac/pictures/8e4c1481-4...
# 3265  https://a2.muscache.com/ac/pictures/30857708/1...
# 1359  https://a2.muscache.com/ac/pictures/77774969/7...
# 3554  https://a0.muscache.com/ac/pictures/83335935/9...
#
#                                          xl_picture_url   host_id  \
# 3809  https://a2.muscache.com/ac/pictures/76273783/b...  31752892
# 2656  https://a2.muscache.com/ac/pictures/8e4c1481-4...   5820099
# 3265  https://a2.muscache.com/ac/pictures/30857708/1...   1704479
# 1359  https://a2.muscache.com/ac/pictures/77774969/7...   4962900
# 3554  https://a0.muscache.com/ac/pictures/83335935/9...    186257
#
#                                         host_url        host_name  host_since  \
# 3809  https://www.airbnb.com/users/show/31752892            Megan  2015-04-22
# 2656   https://www.airbnb.com/users/show/5820099  Forest And Andy  2013-04-07
# 3265   https://www.airbnb.com/users/show/1704479        Kimberley  2012-02-05
# 1359   https://www.airbnb.com/users/show/4962900           Jordan  2013-02-04
# 3554    https://www.airbnb.com/users/show/186257           Nicole  2010-07-30
#
#                            host_location  \
# 3809  Seattle, Washington, United States
# 2656  Seattle, Washington, United States
# 3265  Seattle, Washington, United States
# 1359  Spokane, Washington, United States
# 3554  Seattle, Washington, United States
#
#                                              host_about  host_response_time  \
# 3809                                                NaN        within a day
# 2656  Hello! We are Forest and Andy, two friends who...  within a few hours
# 3265  We are an active family who loves where we liv...                 NaN
# 1359  Stay Alfred was created based on the idea of o...      within an hour
# 3554  Hello! I am an architect and designer in Seatt...                 NaN
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 3809               100%                 100%                 f
# 2656               100%                 100%                 f
# 3265                NaN                  NaN                 f
# 1359                99%                 100%                 f
# 3554                NaN                  NaN                 f
#
#                                      host_thumbnail_url  \
# 3809  https://a2.muscache.com/ac/users/31752892/prof...
# 2656  https://a1.muscache.com/ac/users/5820099/profi...
# 3265  https://a1.muscache.com/ac/users/1704479/profi...
# 1359  https://a1.muscache.com/ac/users/4962900/profi...
# 3554  https://a2.muscache.com/ac/users/186257/profil...
#
#                                        host_picture_url  \
# 3809  https://a2.muscache.com/ac/users/31752892/prof...
# 2656  https://a1.muscache.com/ac/users/5820099/profi...
# 3265  https://a1.muscache.com/ac/users/1704479/profi...
# 1359  https://a1.muscache.com/ac/users/4962900/profi...
# 3554  https://a2.muscache.com/ac/users/186257/profil...
#
#              host_neighbourhood  host_listings_count  \
# 3809                    Fremont                  1.0
# 2656               Capitol Hill                  7.0
# 3265                 Crown Hill                  1.0
# 1359  Central Business District                169.0
# 3554                    Stevens                  1.0
#
#       host_total_listings_count  \
# 3809                        1.0
# 2656                        7.0
# 3265                        1.0
# 1359                      169.0
# 3554                        1.0
#
#                                      host_verifications host_has_profile_pic  \
# 3809   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2656               ['email', 'phone', 'reviews', 'kba']                    t
# 3265               ['email', 'phone', 'reviews', 'kba']                    t
# 1359  ['email', 'phone', 'linkedin', 'reviews', 'jum...                    t
# 3554     ['email', 'phone', 'google', 'reviews', 'kba']                    t
#
#      host_identity_verified  \
# 3809                      t
# 2656                      t
# 3265                      t
# 1359                      t
# 3554                      t
#
#                                                  street neighbourhood  \
# 3809  Albion Place North, Seattle, WA 98103, United ...       Fremont
# 2656   East Denny Way, Seattle, WA 98122, United States  Capitol Hill
# 3265  14th Avenue Northwest, Seattle, WA 98177, Unit...    Crown Hill
# 1359  Westlake Avenue, Seattle, WA 98101, United States      Belltown
# 3554     a 19th Ave E, Seattle, WA 98112, United States       Stevens
#
#       neighbourhood_cleansed neighbourhood_group_cleansed     city state  \
# 3809                 Fremont          Other neighborhoods  Seattle    WA
# 2656                Broadway                 Capitol Hill  Seattle    WA
# 3265  North Beach/Blue Ridge          Other neighborhoods  Seattle    WA
# 1359                Belltown                     Downtown  Seattle    WA
# 3554                 Stevens                 Capitol Hill  Seattle    WA
#
#      zipcode   market smart_location country_code        country   latitude  \
# 3809   98103  Seattle    Seattle, WA           US  United States  47.648689
# 2656   98122  Seattle    Seattle, WA           US  United States  47.619453
# 3265   98177  Seattle    Seattle, WA           US  United States  47.703289
# 1359   98101  Seattle    Seattle, WA           US  United States  47.615290
# 3554   98112  Seattle    Seattle, WA           US  United States  47.622152
#
#        longitude is_location_exact property_type        room_type  \
# 3809 -122.343915                 t     Apartment  Entire home/apt
# 2656 -122.321126                 t         House     Private room
# 3265 -122.375627                 t         House  Entire home/apt
# 1359 -122.337954                 t     Apartment  Entire home/apt
# 3554 -122.307976                 t     Townhouse  Entire home/apt
#
#       accommodates  bathrooms  bedrooms  beds  bed_type  \
# 3809             4        1.0       1.0   1.0  Real Bed
# 2656             2        1.0       1.0   1.0  Real Bed
# 3265             8        1.0       3.0   3.0  Real Bed
# 1359             6        2.0       2.0   3.0  Real Bed
# 3554             4        2.0       2.0   2.0  Real Bed
#
#                                               amenities  square_feet    price  \
# 3809  {"Wheelchair Accessible",Kitchen,Heating,"Fami...          NaN  $120.00
# 2656  {Internet,"Wireless Internet",Heating,"Smoke D...          NaN   $85.00
# 3265  {"Cable TV","Wireless Internet",Kitchen,"Free ...          NaN   $99.00
# 1359  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN  $181.00
# 3554  {TV,Internet,"Wireless Internet",Kitchen,Break...          NaN  $300.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 3809      $600.00     $2,200.00              NaN       $75.00
# 2656          NaN           NaN              NaN       $30.00
# 3265      $650.00     $2,500.00              NaN          NaN
# 1359          NaN           NaN              NaN       $99.00
# 3554    $2,000.00           NaN          $250.00       $50.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 3809                2        $0.00               4              30
# 2656                1       $10.00               1            1125
# 3265                1        $0.00               2            1125
# 1359                1        $0.00               2            1125
# 3554                2       $10.00               1            1125
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 3809     5 months ago                t               30               60
# 2656       3 days ago                t               25               55
# 3265     5 months ago                t                0                0
# 1359            today                t               30               60
# 3554     2 months ago                t                3               33
#
#       availability_90  availability_365 calendar_last_scraped  \
# 3809               90               365            2016-01-04
# 2656               85               356            2016-01-04
# 3265                0               155            2016-01-04
# 1359               90               364            2016-01-04
# 3554               62                62            2016-01-04
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 3809                 10   2015-04-26  2015-08-30                  80.0
# 2656                  0          NaN         NaN                   NaN
# 3265                  4   2014-07-06  2015-02-17                 100.0
# 1359                  9   2015-04-22  2015-11-25                  96.0
# 3554                  4   2015-06-14  2015-08-09                 100.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 3809                     8.0                        7.0
# 2656                     NaN                        NaN
# 3265                     9.0                       10.0
# 1359                    10.0                       10.0
# 3554                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# 3809                    9.0                          9.0
# 2656                    NaN                          NaN
# 3265                   10.0                         10.0
# 1359                   10.0                         10.0
# 3554                   10.0                         10.0
#
#       review_scores_location  review_scores_value requires_license  license  \
# 3809                     9.0                  8.0                f      NaN
# 2656                     NaN                  NaN                f      NaN
# 3265                     9.0                 10.0                f      NaN
# 1359                    10.0                  9.0                f      NaN
# 3554                    10.0                 10.0                f      NaN
#
#      jurisdiction_names instant_bookable cancellation_policy  \
# 3809         WASHINGTON                f              strict
# 2656         WASHINGTON                f            flexible
# 3265         WASHINGTON                f            flexible
# 1359         WASHINGTON                f              strict
# 3554         WASHINGTON                f              strict
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 3809                             f                                f
# 2656                             f                                f
# 3265                             f                                f
# 1359                             f                                f
# 3554                             f                                f
#
#       calculated_host_listings_count  reviews_per_month
# 3809                               1               1.18
# 2656                               7                NaN
# 3265                               1               0.22
# 1359                               1               1.05
# 3554                               1               0.59

# %%
print('Seattle_Listings Shape', Seattle_Listings.shape)

#print(Seattle_Listings.columns)
# Out:
# Seattle_Listings Shape (3818, 92)

# %%
#BNB Listing Graph for Boston and Seattle

# %%
Boston_Listings['host_since'].info()
Boston_Listings['host_since'] = pd.to_datetime(Boston_Listings['host_since'])
Boston_Listings['Hosting_Since_Year'] = Boston_Listings['host_since'].dt.year
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3585 entries, 0 to 3584
# Series name: host_since
# Non-Null Count  Dtype
# --------------  -----
# 3585 non-null   object
# dtypes: object(1)
# memory usage: 28.1+ KB

# %%
Boston_Listings.groupby('Hosting_Since_Year')['id'].count().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Hosting_Since_Year'>

# %%
Seattle_Listings['host_since'].info()
Seattle_Listings['host_since'] = pd.to_datetime(Seattle_Listings['host_since'])
Seattle_Listings['Hosting_Since_Year'] = Seattle_Listings['host_since'].dt.year
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3818 entries, 0 to 3817
# Series name: host_since
# Non-Null Count  Dtype
# --------------  -----
# 3816 non-null   object
# dtypes: object(1)
# memory usage: 30.0+ KB

# %%
Seattle_Listings.groupby('Hosting_Since_Year')['id'].count().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Hosting_Since_Year'>
